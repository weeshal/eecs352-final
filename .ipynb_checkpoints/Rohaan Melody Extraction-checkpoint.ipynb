# %%
#from __future__ import print_function
import sys
sys.path.append('/Users/rohaanadvani/Library/Python/2.7/site-packages'),
import vamp
import librosa
import matplotlib.pyplot as plt
import numpy as np
import math

# %matplotlib inline
from IPython.display import Audio

# %%
def Aud2Str(melody, threshold=1):
    string_out = []
    prev = melody[0]
    for i in range(1,len(melody)):
        curr = melody[i]
        diff = curr - prev
        # if curr < 0 means non-melody section, so we skip
        if curr >= 0:
            s = 's'
            if abs(diff) > threshold:
                s = 'u' if diff>0 else 'd'
                prev = curr
            string_out.append(s)
    return string_out


A4 = 440
C0 = A4*pow(2, -4.75)
name = ["C", "C#", "D", "D#", "E", "F", "F#", "G", "G#", "A", "A#", "B"]
def getNote(freq):
 h = round(12*math.log2(freq/C0))
 octave = h // 12
 n = h % 12
 return name[n]

# %%
# melody is what vamp.collect() returns in data[vector], i.e. melody data
# default vamp hop size is 128/44100
# need to parse data according to desired_hop (in seconds)
# returns melody_desired
def parseMelody(melody, desired_hop):
    default_hop = 128/44100
    jump = int(desired_hop/default_hop)
    index = 0
    melody_desired = []
    while index < len(melody):
        melody_desired.append(melody[index])
        index = index + jump
    melody_desired = np.array(melody_desired)
    return melody_desired

# %%
# example of how to parse melody data
audio, sr = librosa.load('SweetCaroline.wav', sr=44100, mono=True)
# audio = audio[0:15*44100]  #if you want to analyze only section of song
Audio(audio, rate=sr)

data_song = vamp.collect(audio, sr, "mtg-melodia:melodia")
# data is a dictionary containing one item called "vector"
# vector is a tuple of two values: the hop size used for analysis and the array of pitch values
# Note that the hop size is *always* equal to 128/44100.0 = 2.9 ms
h_song, m_song = data_song['vector']

hop = 0.25  #desired hop in seconds
melody_song = parseMelody(m_song, hop)

# %%
timestamps = 8 * 128/44100.0 + np.arange(len(melody_song)) * hop
# Melodia returns unvoiced (=no melody) sections as negative values. So by default, we get:
plt.figure(figsize=(18,6))
plt.plot(timestamps, melody_song)
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
# plt.xlim(0, 15)
plt.show()

# %%
threshold = 1  # play with this to see how it affects performance- essentially if this is high, only larger melody changes will be noted
# out = Aud2Str(melody, threshold)
pos_melody_song = melody_song[melody_song > 0]
out_song = np.array([getNote(xi) for xi in pos_melody_song])
print(out_song)
# Out:
# ['D#' 'G' 'G#' 'G#' 'G#' 'F#' 'D#' 'F#' 'C' 'E' 'F' 'E' 'D#' 'C#' 'D#'
#  'C#' 'D#' 'D#' 'C#' 'C' 'B' 'B' 'B' 'D' 'D#' 'F' 'F#' 'G#' 'E' 'D#' 'E'
#  'E' 'C#' 'B' 'D#' 'D' 'B' 'B' 'B' 'C#' 'C#' 'F#' 'F#' 'C#' 'F#' 'F#' 'F'
#  'F#' 'F' 'F#' 'F#' 'F#' 'G#' 'G' 'G#' 'G#' 'A' 'G#' 'G' 'A' 'B' 'A#' 'A#'
#  'F' 'F#' 'F#' 'F#' 'E' 'B' 'B' 'B' 'B' 'C' 'E' 'E' 'E' 'E' 'E' 'E' 'B'
#  'E' 'D#' 'E' 'D#' 'C#' 'C#' 'B' 'B' 'G' 'F#' 'F' 'F#' 'F' 'F#' 'F#' 'F#'
#  'F#' 'A#' 'A#' 'E' 'C#' 'C#' 'D#' 'D#' 'D#' 'C#' 'D#' 'G#' 'G#' 'G#' 'G#'
#  'E' 'E' 'D#' 'D#' 'G#' 'G#' 'G#' 'G#' 'G#' 'G#' 'E' 'E' 'D' 'C#' 'B' 'G#'
#  'C' 'C#' 'C#' 'C#' 'G' 'F#']

# %%
hum, sr = librosa.load('SweetCarolineHum.wav', sr=44100, mono=True)
# audio = audio[0:15*44100]  #if you want to analyze only section of song
Audio(hum, rate=sr)

data_hum = vamp.collect(hum, sr, "mtg-melodia:melodia")
# data is a dictionary containing one item called "vector"
# vector is a tuple of two values: the hop size used for analysis and the array of pitch values
# Note that the hop size is *always* equal to 128/44100.0 = 2.9 ms
h_hum, m_hum = data_hum['vector']

hop = 0.25  #desired hop in seconds
melody_hum = parseMelody(m_hum, hop)
pos_melody_hum = melody_hum[melody_hum>0]
out_hum = np.array([getNote(xi) for xi in pos_melody_hum])
print(out_hum)

timestamps = 8 * 128/44100.0 + np.arange(len(melody_hum)) * hop
# Melodia returns unvoiced (=no melody) sections as negative values. So by default, we get:
plt.figure(figsize=(18,6))
plt.plot(timestamps, melody_hum)
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
# plt.xlim(0, 15)
plt.show()
# Out:
# ['F' 'E' 'D#' 'D#' 'G' 'A#' 'A' 'A#' 'F' 'E' 'G#' 'G#' 'A' 'A#' 'F' 'E'
#  'F#' 'D#' 'E' 'C#' 'C#' 'B' 'C' 'G#' 'F#' 'G']

# %%
def comparison(hum_string,song_db):
    #hum_string and song_db are strings with the 'u', 'd', 's'
    
    #song_db is a dictionary with song names being the key and the same string... 
    #format as hum_string (but for the current song) for the entire song
    
    #returns array with names of top 3 songs
    hum_string = np.array(hum_string)
    song_scores = {}
    for song_name,song_string in song_db.items():
#         print(song_name)
#         print(song_string)
        chunk_len = len(hum_string)
        curr_song_scores = []
        for i in range(len(song_string)-chunk_len):
            curr_chunk = np.array(song_string[i:chunk_len+i])
            curr_song_scores.append(len(np.where(curr_chunk==hum_string)[0]))   
        song_scores[song_name] = max(curr_song_scores)
        #print(curr_song_scores)
    print(song_scores)
    counted_song_scores = Counter(song_scores)
    top_3 = counted_song_scores.most_common(5)
    top_3_names = [key for key, val in top_3]
    return top_3_names

# %%
song_db={"Sweet Caroline": out_song}
comparison(out_hum, song_db)
# Out:
# {'Sweet Caroline': 8}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-47a435b11122> in <module>
#       1 song_db={"Sweet Caroline": out_song}
# ----> 2 comparison(out_hum, song_db)
#
# <ipython-input-23-bb4c6fc12e06> in comparison(hum_string, song_db)
#      19         #print(curr_song_scores)
#      20     print(song_scores)
# ---> 21     counted_song_scores = Counter(song_scores)
#      22     top_3 = counted_song_scores.most_common(5)
#      23     top_3_names = [key for key, val in top_3]
#
# NameError: name 'Counter' is not defined
